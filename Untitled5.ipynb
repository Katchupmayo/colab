# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %%
data = pd.read_csv (r'./katreese lead 2.txt', sep='\t')
data
# Out:
#        Time   Lead II
# 0      0.00  0.000000
# 1      0.01  0.000000
# 2      0.02  0.000000
# 3      0.03  0.000000
# 4      0.04  0.000000
# ...     ...       ...
# 1390  13.90 -0.060467
# 1391  13.91 -0.068226
# 1392  13.92 -0.095193
# 1393  13.93 -0.064881
# 1394  13.94 -0.088156
#
# [1395 rows x 2 columns]
